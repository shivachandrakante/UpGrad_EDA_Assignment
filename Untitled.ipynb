# %%
import numpy as np
import pandas as pd

# %%
df=pd.read_csv('loan.csv')

# %%
df.head()
# Out:
#         id  member_id  loan_amnt  funded_amnt  funded_amnt_inv        term  \
# 0  1077501    1296599       5000         5000           4975.0   36 months
# 1  1077430    1314167       2500         2500           2500.0   60 months
# 2  1077175    1313524       2400         2400           2400.0   36 months
# 3  1076863    1277178      10000        10000          10000.0   36 months
# 4  1075358    1311748       3000         3000           3000.0   60 months
#
#   int_rate  installment grade sub_grade                 emp_title emp_length  \
# 0   10.65%       162.87     B        B2                       NaN  10+ years
# 1   15.27%        59.83     C        C4                     Ryder   < 1 year
# 2   15.96%        84.33     C        C5                       NaN  10+ years
# 3   13.49%       339.31     C        C1       AIR RESOURCES BOARD  10+ years
# 4   12.69%        67.79     B        B5  University Medical Group     1 year
#
# ...

# %%
df.shape
# Out:
# (39717, 111)

# %%
pd.options.display.max_columns = None
pd.options.display.max_rows = None
df.describe(include='all')
# Out:
#                   id     member_id     loan_amnt   funded_amnt  \
# count   3.971700e+04  3.971700e+04  39717.000000  39717.000000
# unique           NaN           NaN           NaN           NaN
# top              NaN           NaN           NaN           NaN
# freq             NaN           NaN           NaN           NaN
# mean    6.831319e+05  8.504636e+05  11219.443815  10947.713196
# std     2.106941e+05  2.656783e+05   7456.670694   7187.238670
# min     5.473400e+04  7.069900e+04    500.000000    500.000000
# 25%     5.162210e+05  6.667800e+05   5500.000000   5400.000000
# 50%     6.656650e+05  8.508120e+05  10000.000000   9600.000000
# 75%     8.377550e+05  1.047339e+06  15000.000000  15000.000000
# max     1.077501e+06  1.314167e+06  35000.000000  35000.000000
#
#         funded_amnt_inv        term int_rate   installment  grade sub_grade  \
# count      39717.000000       39717    39717  39717.000000  39717     39717
# ...

# %%
list_of_columns_to_drop=['mths_since_last_major_derog','annual_inc_joint','dti_joint','verification_status_joint',
                         'tot_coll_amt','tot_cur_bal','open_acc_6m','open_il_6m','open_il_12m','open_il_24m',
                         'mths_since_rcnt_il','total_bal_il','il_util','open_rv_12m','open_rv_24m','max_bal_bc','all_util',
                         'total_rev_hi_lim','inq_fi','total_cu_tl','inq_last_12m','acc_open_past_24mths','avg_cur_bal',
                         'bc_open_to_buy','bc_util','mo_sin_old_il_acct','mo_sin_old_rev_tl_op','mo_sin_rcnt_rev_tl_op',
                         'mo_sin_rcnt_tl','mort_acc','mths_since_recent_bc','mths_since_recent_bc_dlq','mths_since_recent_inq',
                         'mths_since_recent_revol_delinq','num_accts_ever_120_pd','num_actv_bc_tl','num_actv_rev_tl',
                         'num_bc_sats','num_bc_tl','num_il_tl','num_op_rev_tl','num_rev_accts','num_rev_tl_bal_gt_0','num_sats',
                         'num_tl_120dpd_2m','num_tl_30dpd','num_tl_90g_dpd_24m','num_tl_op_past_12m','pct_tl_nvr_dlq',
                         'percent_bc_gt_75','tot_hi_cred_lim','total_bal_ex_mort','total_bc_limit','total_il_high_credit_limit']

# %%
df.drop(list_of_columns_to_drop,inplace=True,axis=1)

# %%
df.shape
# Out:
# (39717, 57)

# %%
df.describe(include='all')
# Out:
#                   id     member_id     loan_amnt   funded_amnt  \
# count   3.971700e+04  3.971700e+04  39717.000000  39717.000000
# unique           NaN           NaN           NaN           NaN
# top              NaN           NaN           NaN           NaN
# freq             NaN           NaN           NaN           NaN
# mean    6.831319e+05  8.504636e+05  11219.443815  10947.713196
# std     2.106941e+05  2.656783e+05   7456.670694   7187.238670
# min     5.473400e+04  7.069900e+04    500.000000    500.000000
# 25%     5.162210e+05  6.667800e+05   5500.000000   5400.000000
# 50%     6.656650e+05  8.508120e+05  10000.000000   9600.000000
# 75%     8.377550e+05  1.047339e+06  15000.000000  15000.000000
# max     1.077501e+06  1.314167e+06  35000.000000  35000.000000
#
#         funded_amnt_inv        term int_rate   installment  grade sub_grade  \
# count      39717.000000       39717    39717  39717.000000  39717     39717
# ...

# %%
print(df['id'].duplicated().any())
print(df['member_id'].duplicated().any())
print(df['url'].duplicated().any())
print(df['pymnt_plan'].duplicated().any(),df['pymnt_plan'].unique())
print(df['initial_list_status'].duplicated().any(),df['initial_list_status'].unique())
print(df['acc_now_delinq'].duplicated().any(),df['acc_now_delinq'].unique())
print(df['application_type'].duplicated().any(),df['application_type'].unique())
print(df['chargeoff_within_12_mths'].duplicated().any(),df['chargeoff_within_12_mths'].unique())
print(df['delinq_amnt'].duplicated().any(),df['delinq_amnt'].unique())
print(df['tax_liens'].duplicated().any(),df['tax_liens'].unique())
# Out:
# False
# False
# False
# True ['n']
# True ['f']
# True [0]
# True ['INDIVIDUAL']
# True [ 0. nan]
# True [0]
# True [ 0. nan]

# %%
#Dropping unique values
df.drop(['id','member_id','url','pymnt_plan','initial_list_status','acc_now_delinq','application_type',
         'chargeoff_within_12_mths','delinq_amnt','tax_liens'],inplace=True,axis=1)

# %%
df.isnull().sum()/df.shape[0]*100
# Out:
# loan_amnt                      0.000000
# funded_amnt                    0.000000
# funded_amnt_inv                0.000000
# term                           0.000000
# int_rate                       0.000000
# installment                    0.000000
# grade                          0.000000
# sub_grade                      0.000000
# emp_title                      6.191303
# emp_length                     2.706650
# home_ownership                 0.000000
# annual_inc                     0.000000
# verification_status            0.000000
# issue_d                        0.000000
# loan_status                    0.000000
# desc                          32.580507
# purpose                        0.000000
# title                          0.027696
# zip_code                       0.000000
# addr_state                     0.000000
# dti                            0.000000
# delinq_2yrs                    0.000000
# earliest_cr_line               0.000000
# ...

# %%
#Removing Columns having more than 90% Null Values
df.drop(['next_pymnt_d','mths_since_last_record'],inplace=True,axis=1)

# %%
df.desc
# Out:
# 0          Borrower added on 12/22/11 > I need to upgra...
# 1          Borrower added on 12/22/11 > I plan to use t...
# 2                                                      NaN
# 3          Borrower added on 12/21/11 > to pay for prop...
# 4          Borrower added on 12/21/11 > I plan on combi...
# 5                                                      NaN
# 6          Borrower added on 12/18/11 > I am planning o...
# 7          Borrower added on 12/16/11 > Downpayment for...
# 8          Borrower added on 12/21/11 > I own a small h...
# 9          Borrower added on 12/16/11 > I'm trying to b...
# 10         Borrower added on 12/15/11 > I had recived a...
# 11                                                     NaN
# 12         Borrower added on 12/15/11 > Plan to pay off...
# 13         Borrower added on 12/19/11 > I intend to pay...
# 14                                                     NaN
# 15                                                     NaN
# ...

# %%
df['home_ownership'].unique()
# Out:
# array(['RENT', 'OWN', 'MORTGAGE', 'OTHER', 'NONE'], dtype=object)

# %%
df['emp_length'].unique()
# Out:
# array(['10+ years', '< 1 year', '1 year', '3 years', '8 years', '9 years',
#        '4 years', '5 years', '6 years', '2 years', '7 years', nan],
#       dtype=object)

# %%
df['emp_title'].unique()
# Out:
# array([nan, 'Ryder', 'AIR RESOURCES BOARD', ..., 'FiSite Research',
#        'Squarewave Solutions, Ltd.', 'Evergreen Center'], dtype=object)

# %%
df['grade'].unique()
# Out:
# array(['B', 'C', 'A', 'E', 'F', 'D', 'G'], dtype=object)

# %%
df['sub_grade'].unique()
# Out:
# array(['B2', 'C4', 'C5', 'C1', 'B5', 'A4', 'E1', 'F2', 'C3', 'B1', 'D1',
#        'A1', 'B3', 'B4', 'C2', 'D2', 'A3', 'A5', 'D5', 'A2', 'E4', 'D3',
#        'D4', 'F3', 'E3', 'F4', 'F1', 'E5', 'G4', 'E2', 'G3', 'G2', 'G1',
#        'F5', 'G5'], dtype=object)

# %%
df['int_rate'].unique()
# Out:
# array(['10.65%', '15.27%', '15.96%', '13.49%', '12.69%', '7.90%',
#        '18.64%', '21.28%', '14.65%', '9.91%', '16.29%', '6.03%', '11.71%',
#        '12.42%', '14.27%', '16.77%', '7.51%', '8.90%', '18.25%', '6.62%',
#        '19.91%', '17.27%', '17.58%', '21.67%', '19.42%', '22.06%',
#        '20.89%', '20.30%', '23.91%', '19.03%', '23.52%', '23.13%',
#        '22.74%', '22.35%', '24.11%', '6.00%', '22.11%', '7.49%', '11.99%',
#        '5.99%', '10.99%', '9.99%', '18.79%', '11.49%', '8.49%', '15.99%',
#        '16.49%', '6.99%', '12.99%', '15.23%', '14.79%', '5.42%', '10.59%',
#        '17.49%', '15.62%', '21.36%', '19.29%', '13.99%', '18.39%',
#        '16.89%', '17.99%', '20.62%', '20.99%', '22.85%', '19.69%',
#        '20.25%', '23.22%', '21.74%', '22.48%', '23.59%', '12.62%',
#        '18.07%', '11.63%', '7.91%', '7.42%', '11.14%', '20.20%', '12.12%',
#        '19.39%', '16.11%', '17.54%', '22.64%', '13.84%', '16.59%',
# ...

# %%
df['revol_util'].unique()
# Out:
# array(['83.70%', '9.40%', '98.50%', ..., '49.63%', '0.04%', '7.28%'],
#       dtype=object)

# %%
df['issue_d'].unique()
# Out:
# array(['Dec-11', 'Nov-11', 'Oct-11', 'Sep-11', 'Aug-11', 'Jul-11',
#        'Jun-11', 'May-11', 'Apr-11', 'Mar-11', 'Feb-11', 'Jan-11',
#        'Dec-10', 'Nov-10', 'Oct-10', 'Sep-10', 'Aug-10', 'Jul-10',
#        'Jun-10', 'May-10', 'Apr-10', 'Mar-10', 'Feb-10', 'Jan-10',
#        'Dec-09', 'Nov-09', 'Oct-09', 'Sep-09', 'Aug-09', 'Jul-09',
#        'Jun-09', 'May-09', 'Apr-09', 'Mar-09', 'Feb-09', 'Jan-09',
#        'Dec-08', 'Nov-08', 'Oct-08', 'Sep-08', 'Aug-08', 'Jul-08',
#        'Jun-08', 'May-08', 'Apr-08', 'Mar-08', 'Feb-08', 'Jan-08',
#        'Dec-07', 'Nov-07', 'Oct-07', 'Sep-07', 'Aug-07', 'Jul-07',
#        'Jun-07'], dtype=object)

# %%
df['last_credit_pull_d'].unique()
# Out:
# array(['May-16', 'Sep-13', 'Apr-16', 'Jan-16', 'Dec-14', 'Aug-12',
#        'Mar-13', 'Dec-15', 'Aug-13', 'Nov-12', 'Mar-14', 'Apr-15',
#        'May-14', 'Jul-15', 'Feb-16', 'Mar-16', 'Sep-12', 'May-13',
#        'Jan-15', 'Jun-12', 'Mar-15', 'Dec-12', 'Sep-14', 'Feb-14',
#        'Jun-15', 'Oct-13', 'Apr-14', 'Oct-14', 'Feb-13', 'Nov-15',
#        'Jul-14', 'Sep-15', 'Oct-12', 'Nov-13', 'Nov-14', 'Feb-12',
#        'Oct-15', 'Apr-12', 'Aug-15', 'Jun-14', 'Jan-12', 'Aug-14',
#        'Jun-13', 'Dec-13', 'May-12', 'Jul-12', 'Jan-14', 'Jul-13',
#        'Apr-13', 'May-15', 'Feb-15', 'Mar-12', 'Nov-11', 'Dec-11',
#        'Jan-13', 'Oct-11', 'Sep-11', 'Aug-11', 'Jul-11', 'Jun-11',
#        'May-11', 'Apr-11', 'Mar-11', 'Feb-11', 'Jan-11', 'Dec-10',
#        'Nov-10', 'Oct-10', nan, 'Sep-10', 'Aug-10', 'Jul-10', 'Jun-10',
#        'May-10', 'Apr-10', 'Feb-10', 'Mar-10', 'Aug-07', 'Jan-10',
#        'Dec-09', 'Nov-09', 'Oct-09', 'Sep-09', 'Jul-09', 'Aug-09',
# ...

# %%
df['last_pymnt_d'].unique()
# Out:
# array(['Jan-15', 'Apr-13', 'Jun-14', 'May-16', 'Apr-12', 'Nov-12',
#        'Jun-13', 'Sep-13', 'Jul-12', 'Oct-13', 'May-13', 'Feb-15',
#        'Aug-15', 'Oct-12', 'Sep-12', nan, 'Dec-12', 'Dec-14', 'Aug-13',
#        'Nov-13', 'Jan-14', 'Apr-14', 'Aug-14', 'Oct-14', 'Aug-12',
#        'Jul-14', 'Jul-13', 'Jan-16', 'Feb-16', 'Apr-15', 'Feb-14',
#        'Sep-14', 'Jun-12', 'Feb-13', 'Mar-13', 'May-14', 'Mar-15',
#        'Jan-13', 'Dec-13', 'Feb-12', 'Mar-14', 'Sep-15', 'Nov-15',
#        'Mar-16', 'Jan-12', 'Oct-15', 'Nov-14', 'Mar-12', 'May-12',
#        'Apr-16', 'Dec-15', 'Jun-15', 'May-15', 'Jul-15', 'Dec-11',
#        'Nov-11', 'Oct-11', 'Sep-11', 'Aug-11', 'Jul-11', 'Jun-11',
#        'May-11', 'Apr-11', 'Mar-11', 'Feb-11', 'Jan-11', 'Dec-10',
#        'Nov-10', 'Oct-10', 'Sep-10', 'Aug-10', 'Jul-10', 'Jun-10',
#        'May-10', 'Apr-10', 'Mar-10', 'Feb-10', 'Jan-10', 'Dec-09',
#        'Nov-09', 'Oct-09', 'Sep-09', 'Aug-09', 'Jul-09', 'Jun-09',
# ...

# %%
print(len(df['revol_util'].unique()))
print(df['revol_util'].unique())
# Out:
# 1090
# ['83.70%' '9.40%' '98.50%' ... '49.63%' '0.04%' '7.28%']

# %%
df['term'].unique()
# Out:
# array([' 36 months', ' 60 months'], dtype=object)

# %%
df['title'].unique()
# Out:
# array(['Computer', 'bike', 'real estate business', ...,
#        'Retiring credit card debt', 'MBA Loan Consolidation', 'JAL Loan'],
#       dtype=object)

# %%
len(df['zip_code'].unique())
# Out:
# 823

# %%
df['verification_status'].unique()
# Out:
# array(['Verified', 'Source Verified', 'Not Verified'], dtype=object)

# %%
df['loan_status'].unique()
# Out:
# array(['Fully Paid', 'Charged Off', 'Current'], dtype=object)

# %%
df['purpose'].unique()
# Out:
# array(['credit_card', 'car', 'small_business', 'other', 'wedding',
#        'debt_consolidation', 'home_improvement', 'major_purchase',
#        'medical', 'moving', 'vacation', 'house', 'renewable_energy',
#        'educational'], dtype=object)

# %%
df['title'].unique()
# Out:
# array(['Computer', 'bike', 'real estate business', ...,
#        'Retiring credit card debt', 'MBA Loan Consolidation', 'JAL Loan'],
#       dtype=object)

# %%
df['addr_state'].unique()
# Out:
# array(['AZ', 'GA', 'IL', 'CA', 'OR', 'NC', 'TX', 'VA', 'MO', 'CT', 'UT',
#        'FL', 'NY', 'PA', 'MN', 'NJ', 'KY', 'OH', 'SC', 'RI', 'LA', 'MA',
#        'WA', 'WI', 'AL', 'CO', 'KS', 'NV', 'AK', 'MD', 'WV', 'VT', 'MI',
#        'DC', 'SD', 'NH', 'AR', 'NM', 'MT', 'HI', 'WY', 'OK', 'DE', 'MS',
#        'TN', 'IA', 'NE', 'ID', 'IN', 'ME'], dtype=object)

# %%
df['earliest_cr_line'].unique()
# Out:
# array(['Jan-85', 'Apr-99', 'Nov-01', 'Feb-96', 'Jan-96', 'Nov-04',
#        'Jul-05', 'Jan-07', 'Apr-04', 'Sep-04', 'Jan-98', 'Oct-89',
#        'Jul-03', 'May-91', 'Sep-07', 'Oct-98', 'Aug-93', 'Oct-03',
#        'Jan-01', 'Nov-97', 'Feb-83', 'Jul-85', 'Apr-03', 'Jun-01',
#        'Feb-02', 'Aug-84', 'Nov-06', 'Dec-87', 'Nov-81', 'Feb-97',
#        'Apr-05', 'Oct-07', 'Dec-00', 'Apr-07', 'Dec-01', 'Jan-03',
#        'Mar-94', 'Sep-98', 'Jun-04', 'Nov-95', 'Jul-99', 'Jun-95',
#        'Sep-92', 'Jan-02', 'Apr-92', 'Oct-06', 'May-00', 'Dec-98',
#        'Dec-04', 'Oct-00', 'May-02', 'May-06', 'Jul-02', 'Jul-06',
#        'May-97', 'Oct-05', 'Apr-95', 'Oct-02', 'Jan-00', 'Apr-00',
#        'Dec-94', 'Sep-05', 'Dec-84', 'Dec-99', 'Nov-03', 'Jun-89',
#        'Jun-03', 'Oct-96', 'May-03', 'Jun-02', 'Jun-07', 'Dec-96',
#        'Feb-84', 'Sep-02', 'Jan-86', 'May-98', 'Jan-97', 'Jun-05',
#        'Feb-90', 'Mar-04', 'Jul-95', 'Aug-94', 'Jun-92', 'Mar-97',
# ...

# %%
df.describe(include='all')
# Out:
#            loan_amnt   funded_amnt  funded_amnt_inv        term int_rate  \
# count   39717.000000  39717.000000     39717.000000       39717    39717
# unique           NaN           NaN              NaN           2      371
# top              NaN           NaN              NaN   36 months   10.99%
# freq             NaN           NaN              NaN       29096      956
# mean    11219.443815  10947.713196     10397.448868         NaN      NaN
# std      7456.670694   7187.238670      7128.450439         NaN      NaN
# min       500.000000    500.000000         0.000000         NaN      NaN
# 25%      5500.000000   5400.000000      5000.000000         NaN      NaN
# 50%     10000.000000   9600.000000      8975.000000         NaN      NaN
# 75%     15000.000000  15000.000000     14400.000000         NaN      NaN
# max     35000.000000  35000.000000     35000.000000         NaN      NaN
#
#          installment  grade sub_grade emp_title emp_length home_ownership  \
# ...

# %%
df.dtypes
# Out:
# loan_amnt                       int64
# funded_amnt                     int64
# funded_amnt_inv               float64
# term                           object
# int_rate                       object
# installment                   float64
# grade                          object
# sub_grade                      object
# emp_title                      object
# emp_length                     object
# home_ownership                 object
# annual_inc                    float64
# verification_status            object
# issue_d                        object
# loan_status                    object
# desc                           object
# purpose                        object
# title                          object
# zip_code                       object
# addr_state                     object
# dti                           float64
# delinq_2yrs                     int64
# earliest_cr_line               object
# inq_last_6mths                  int64
# mths_since_last_delinq        float64
# ...

# %%
df['loan_status'].unique()
# Out:
# array(['Fully Paid', 'Charged Off'], dtype=object)

# %%
df=df[df['loan_status']!='Current']

# %%
df['loan_status'].unique()
# Out:
# array(['Fully Paid', 'Charged Off'], dtype=object)

# %%
df['Fully_Paid']=df.loan_status.apply(lambda x:1 if x=='Fully Paid' else 0)

# %%
df.shape
# Out:
# (38577, 46)

# %%
df['loan_status'].value_counts()
# Out:
# Fully Paid     32950
# Charged Off     5627
# Name: loan_status, dtype: int64

# %%
df['Fully_Paid'].value_counts()
# Out:
# 1    32950
# 0     5627
# Name: Fully_Paid, dtype: int64

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
sns.boxplot(y='loan_amnt',x='loan_status',data=df)

# %% [markdown]
# ##### From the above diagram we can see that the median of loan_amount of charged-off people is high.

# %%
df.groupby(['term'])['loan_status'].value_counts(normalize=True)
# Out:
# term        loan_status
#  36 months  Fully Paid     0.889091
#             Charged Off    0.110909
#  60 months  Fully Paid     0.746862
#             Charged Off    0.253138
# Name: loan_status, dtype: float64

# %% [markdown]
# ###### From the above statestics we can say that the people who are taking for 5 years term are most likely to be charged-off

# %%
data=sorted(df['annual_inc'],reverse=True)
data={'rank':np.arange(1,len(data)+1).astype('int'),'annual_income':data}
data=pd.DataFrame(data)
data.head()
# Out:
#    rank  annual_income
# 0     1      6000000.0
# 1     2      3900000.0
# 2     3      2039784.0
# 3     4      1900000.0
# 4     5      1782000.0

# %%
sns.lineplot(x=data['rank'],y=data['annual_income'])
plt.yscale('log')
plt.xscale('log')

# %%
df['issue_d']=pd.to_datetime(df['issue_d'],format='%b-%y')

# %%
df['issue_year']=df.issue_d.dt.year
df['issue_month']=df.issue_d.dt.month
df.drop(['issue_d'],axis=1,inplace=True)

# %%
sns.countplot(x='issue_year',hue='loan_status',data=df)

# %%
sns.countplot(x='issue_month',hue='loan_status',data=df)

# %%
sns.lineplot(x='issue_month',y='int_rate',data=df)

# %%
sns.lineplot(x='issue_year',y='int_rate',data=df)

# %% [markdown]
# ###### From the above lineplot we can see that the after stedy increase of intrest from the year 2007 the intrest rate got decreased from 2009 to 2010. The main reason would be Recession.

# %%
df['difference_bt_requested_and_funded']=(df['loan_amnt']-df['funded_amnt']).apply(lambda x: 1 if x!=0 else 0)

# %%
df['difference_bt_requested_and_funded'].value_counts()
# Out:
# 0    37868
# 1     1849
# Name: difference_bt_requested_and_funded, dtype: int64

# %%
df.corr()
# Out:
#                                     loan_amnt  funded_amnt  funded_amnt_inv  \
# loan_amnt                            1.000000     0.981578         0.940034
# funded_amnt                          0.981578     1.000000         0.958422
# funded_amnt_inv                      0.940034     0.958422         1.000000
# installment                          0.930288     0.956159         0.905039
# annual_inc                           0.271149     0.266965         0.254375
# dti                                  0.066439     0.066283         0.074689
# delinq_2yrs                         -0.031864    -0.032355        -0.038501
# inq_last_6mths                       0.009229     0.009259        -0.005712
# mths_since_last_delinq               0.014871     0.016359         0.071924
# open_acc                             0.177168     0.175530         0.163027
# pub_rec                             -0.051236    -0.052169        -0.053214
# ...

# %%
df['revol_util'].isnull().sum()

# %%
df.dropna(subset=['revol_util'],inplace=True)

# %%
df['revol_util'].isnull().sum()
# Out:
# 0

# %%
df['revol_util_range']=df['revol_util'].apply(lambda x:float(x.strip('%')))

# %%
def revol_range(column):
    if(column<=10):
        return 1
    elif(column>10 and column<=20):
        return 2
    elif(column>20 and column<=30):
        return 3
    elif(column>30 and column<=40):
        return 4
    elif(column>40 and column<=50):
        return 5
    elif(column>50 and column<=60):
        return 6
    elif(column>60 and column<=70):
        return 7
    elif(column>70 and column<=80):
        return 8
    elif(column>80 and column<=90):
        return 9
    elif(column>90 and column<=100):
        return 10
    
    
    
df['revol_util_range']=df['revol_util_range'].apply(revol_range)

# %%
df['revol_util_range'].describe()
# Out:
# count    39667.000000
# mean         5.392291
# std          2.804935
# min          1.000000
# 25%          3.000000
# 50%          5.000000
# 75%          8.000000
# max         10.000000
# Name: revol_util_range, dtype: float64

# %%
plt.hist(df['revol_util_range'])
plt.show()

# %%
df['int_rate']=df['int_rate'].apply(lambda x:float(x.strip('%')))

# %%
def fun(column):
    if(column<=10):
        return 1
    elif(column>10 and column<=15):
        return 2
    elif(column>15 and column<=20):
        return 3
    elif(column>20 and column<=25):
        return 4
    
    
df['intrest_rate_range']=df['int_rate'].apply(fun)

# %%
df['intrest_rate_range'].value_counts()
# Out:
# 2    18774
# 1    12393
# 3     7631
# 4      869
# Name: intrest_rate_range, dtype: int64

# %%
df['dti'].describe()
# Out:
# count    39667.000000
# mean        13.318704
# std          6.676975
# min          0.000000
# 25%          8.180000
# 50%         13.410000
# 75%         18.600000
# max         29.990000
# Name: dti, dtype: float64

# %%
def fun(column):
    if(column<=6):
        return 1
    elif(column>6 and column<=12):
        return 2
    elif(column>12 and column<=18):
        return 3
    elif(column>18 and column<=24):
        return 4
    else:
        return 5
    
    
df['dti_range']=df['dti'].apply(fun)

# %%
df['collection_recovery_fee'].value_counts()

# %%
df['fico_range_high'].describe()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\Anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    2656             try:
# -> 2657                 return self._engine.get_loc(key)
#    2658             except KeyError:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'fico_range_high'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-102-db79e29e0c47> in <module>
# ----> 1 df['fico_range_high'].describe()
#
# ...

# %%
plt.hist(df['Fully_Paid'])
plt.show()

# %%
df['annual_inc'].describe()
# Out:
# count    3.852700e+04
# mean     6.880923e+04
# std      6.421493e+04
# min      4.000000e+03
# 25%      4.000000e+04
# 50%      5.900000e+04
# 75%      8.200000e+04
# max      6.000000e+06
# Name: annual_inc, dtype: float64

# %%
plt.hist(df['annual_inc'])
plt.xscale('log')
plt.yscale('log')
plt.show()

# %%
sns.barplot(x='revol_util_range', y='delinq_2yrs',hue='Fully_Paid', data=df)
plt.show()

# %%
sns.countplot(x=df['revol_util_range'],hue=df['loan_status'],)

# %%
df['loan_amnt'].describe()
# Out:
# count    38527.000000
# mean     11055.265139
# std       7348.433587
# min        500.000000
# 25%       5325.000000
# 50%       9600.000000
# 75%      15000.000000
# max      35000.000000
# Name: loan_amnt, dtype: float64

# %%
sns.boxplot(x=df['loan_status'],y=df['loan_amnt'])
plt.show()

# %%
df['revol_bal'].describe()
# Out:
# count     38527.000000
# mean      13305.458795
# std       15868.644361
# min           0.000000
# 25%        3667.000000
# 50%        8777.000000
# 75%       16930.000000
# max      149588.000000
# Name: revol_bal, dtype: float64

# %%
df['revol_util'].value_counts()

# %%
sns.boxplot(x=df['loan_status'],y=df['loan_amnt'])
#plt.yscale('log')
plt.show()

# %%
sns.boxplot(x=df['loan_status'],y=df['installment'])
#plt.yscale('log')
plt.show()

# %%
sns.boxplot(x=df['loan_status'],y=df['mths_since_last_delinq'])
#plt.yscale('log')
plt.show()

# %%
sns.boxplot(x=df['term'],y=df['loan_amnt'])
#plt.yscale('log')
plt.show()

# %%
sns.boxplot(x=df['loan_status'],y=df['loan_amnt'])
#plt.yscale('log')
plt.show()

# %%
sns.boxplot(x=df['loan_status'],y=df['open_acc'])
#plt.yscale('log')
plt.show()

# %%
sns.boxplot(x=df['loan_status'],y=df['loan_amnt'])
#plt.yscale('log')
plt.show()

# %%
sns.barplot(x='loan_status', y='mths_since_last_delinq',hue='home_ownership', data=df)
plt.show()

# %%
sns.barplot(x='loan_status', y='open_acc',hue='home_ownership', data=df)
plt.show()

# %%
sns.barplot(x='loan_status', y='installment',hue='term', data=df)
plt.show()

# %%
df['installment'].describe()

# %%
sns.boxplot(y='installment',data=df)

# %%
df['delinq_2yrs'].value_counts()

# %%
sns.barplot( x='delinq_2yrs',hue='loan_status', data=df)
plt.show()

# %%
df['delinq_2yrs']

# %%
sns.countplot(x="delinq_2yrs",hue='loan_status',data=df)
plt.yscale('log')

# %%
sns.catplot(x='loan_status', y="delinq_2yrs", data=df)

# %%
df['collection_recovery_fee'].describe()

# %%
df['loan_status'].value_counts()

# %%
df.isnull().sum()

# %%
sns.barplot(x='loan_status', y='dti_range', data=df)
plt.show()

# %%
sns.catplot(x='loan_status', y="dti_range", data=df)

# %%
sns.countplot(x="dti_range",hue='loan_status',data=df)
#plt.yscale('log')

# %%
df.shape
# Out:
# (38527, 50)

# %%
df['collection_recovery_fee'].describe()
# Out:
# count    38527.000000
# mean        12.753315
# std        150.879911
# min          0.000000
# 25%          0.000000
# 50%          0.000000
# 75%          0.000000
# max       7002.190000
# Name: collection_recovery_fee, dtype: float64

# %%
# Out:
# 0.0000       34759
# 2.0000          12
# 1.2000          10
# 3.7100           9
# 1.8800           8
# 2.5200           8
# 2.0200           8
# 1.2100           8
# 1.6900           8
# 1.6000           8
# 0.8000           8
# 4.5200           7
# 3.3900           7
# 3.2300           7
# 1.8000           7
# 0.9300           7
# 3.2000           7
# 1.5500           7
# 1.2200           7
# 1.0700           7
# 1.6200           7
# 4.0000           7
# 3.0000           7
# 3.9600           6
# 4.9500           6
# 4.7300           6
# 2.3000           6
# 2.0100           6
# 1.9000           6
# 0.6000           6
# 1.4800           6
# 2.3600           6
# 2.4800           6
# 3.3500           6
# 0.6500           6
# 0.8100           6
# 4.8000           6
# 2.2800           6
# 1.1100           6
# 2.0800           6
# 2.8700           6
# 3.0900           6
# 0.9400           6
# 1.4400           6
# 4.1600           6
# 2.5700           6
# 1.3900           6
# ...

# %%
df.dtypes
# Out:
# loan_amnt                               int64
# funded_amnt                             int64
# funded_amnt_inv                       float64
# term                                   object
# int_rate                               object
# installment                           float64
# grade                                  object
# sub_grade                              object
# emp_title                              object
# emp_length                             object
# home_ownership                         object
# annual_inc                            float64
# verification_status                    object
# issue_d                                object
# loan_status                            object
# desc                                   object
# purpose                                object
# title                                  object
# zip_code                               object
# addr_state                             object
# ...
